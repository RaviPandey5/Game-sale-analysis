# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Data for Project 1 (1).csv")

# %%
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16598, step=1)

# %%
data.head
# Out:
# <bound method NDFrame.head of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.sum()
# Out:
# <ipython-input-13-1a71ea4920a7>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.sum()
# Rank                                                    137773446
# Name            Wii SportsSuper Mario Bros.Mario Kart WiiWii S...
# Platform        WiiNESWiiWiiGBGBDSWiiWiiNESDSDSGBWiiWiiX360PS3...
# Year                                                   32758598.0
# Genre           SportsPlatformRacingSportsRole-PlayingPuzzlePl...
# NA_Sales                                                  4392.95
# EU_Sales                                                  2434.13
# JP_Sales                                                  1291.02
# Other_Sales                                                797.75
# ...

# %%
data["Name"]
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
data.iloc[:4]
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
# 3     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00

# %%
#Q2 A
na=data.dropna()
na
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
na.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
#Q2 B
na["Year"].apply(int)
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16593    2002
# 16594    2003
# 16595    2008
# 16596    2010
# 16597    2003
# Name: Year, Length: 16291, dtype: int64

# %%
#Q3

NA = na['NA_Sales'].sum()
EU = na['EU_Sales'].sum()
JP = na['JP_Sales'].sum()
OT = na['Other_Sales'].sum()
GL = na['Global_Sales'].sum()

sales = [NA,EU,JP,OT,GL]

group_year = pd.DataFrame(sales, columns=['Sales'])
group_year
# Out:
#      Sales
# 0  4327.65
# 1  2406.69
# 2  1284.27
# 3   788.91
# 4  8811.97

# %%
na
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
last = na.tail(5)
last[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
# Out:
# NA_Sales        0.03
# EU_Sales        0.01
# JP_Sales        0.00
# Other_Sales     0.00
# Global_Sales    0.05
# dtype: float64

# %%
#a = na[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales',]]
#b = a.sum(axis=1)
#c = b.max()
#na.groupby(['Genre'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
a = na[['Year','Global_Sales']]
a.sort_values("Global_Sales",ascending=False)
# Out:
#          Year  Global_Sales
# 0      2006.0         82.74
# 1      1985.0         40.24
# 2      2008.0         35.82
# 3      2009.0         33.00
# 4      1996.0         31.37
# ...       ...           ...
# 16183  2013.0          0.01
# 16184  2007.0          0.01
# 16185  2009.0          0.01
# 16186  2009.0          0.01
# 16597  2003.0          0.01
#
# [16291 rows x 2 columns]

# %%
import pandas as pd

data = [['Ravi', 50,8584563214], ['Nandani', 45,512436425], ['Uday', 65,984874547],['Ravi', 50,8584563214], ['Nandani', 45,512436425], ['Uday', 65,984874547],['Ravi', 50,8584563214], ['Nandani', 45,512436425], ['Uday', 65,984874547]]

test = pd.DataFrame(data, columns = ['Name', 'Marks','Contact'])



dis = {"name":["ravi","nandani","uday"],"marks":[45,50,90],"contact":[8584563214,984874547,8584563214]}

test2 = pd.DataFrame(dis)

test2
# Out:
#       name  marks     contact
# 0     ravi     45  8584563214
# 1  nandani     50   984874547
# 2     uday     90  8584563214

# %%
a1 = na[['Genre','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']]

# %%
#Q4
jpmax= na[['Genre','JP_Sales']]
jpmax.max()
# Out:
# Genre       Strategy
# JP_Sales       10.22
# dtype: object

# %%
#Q4
na.groupby(['Genre'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          861.77    516.48    158.65       184.92       1722.84
# Adventure       101.93     63.74     51.99        16.70        234.59
# Fighting        220.74    100.00     87.15        36.19        444.05
# Misc            396.92    211.77    106.67        73.92        789.87
# Platform        445.99    200.65    130.65        51.51        829.13
# Puzzle          122.01     50.52     56.68        12.47        242.21
# Racing          356.93    236.31     56.61        76.68        726.76
# Role-Playing    326.50    187.57    350.29        59.38        923.83
# Shooter         575.16    310.45     38.18       101.90       1026.20
# Simulation      181.78    113.02     63.54        31.36        389.98
# Sports          670.09    371.34    134.76       132.65       1309.24
# Strategy         67.83     44.84     49.10        11.23        173.27

# %%
#Q4
asi= a1.tail(5).sum()
asi
# Out:
# Genre           PlatformShooterRacingPuzzlePlatform
# NA_Sales                                       0.03
# EU_Sales                                       0.01
# JP_Sales                                        0.0
# Other_Sales                                     0.0
# Global_Sales                                   0.05
# dtype: object

# %%
#Q4
na.sort_values("Global_Sales",ascending=False)
# Out:
#         Rank                                             Name Platform  \
# 0          1                                       Wii Sports      Wii
# 1          2                                Super Mario Bros.      NES
# 2          3                                   Mario Kart Wii      Wii
# 3          4                                Wii Sports Resort      Wii
# 4          5                         Pokemon Red/Pokemon Blue       GB
# ...      ...                                              ...      ...
# 16183  16186                      Sakura-Sou no Pet na Kanojo      PSP
# 16184  16187  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2
# 16185  16188           Tantei Jinguuji Saburo: Hai to Diamond      PSP
# 16186  16189                                      BattleForge       PC
# 16597  16600                                 Spirits & Spells      GBA
#
#          Year         Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Q5
na.groupby(['Publisher'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios                   0.07      0.04      0.00         0.00
# 1C Company                        0.01      0.07      0.00         0.02
# 20th Century Fox Video Games      1.82      0.10      0.00         0.01
# 2D Boy                            0.00      0.03      0.00         0.01
# 3DO                               6.48      3.04      0.00         0.63
# ...                                ...       ...       ...          ...
# id Software                       0.02      0.00      0.00         0.00
# imageepoch Inc.                   0.00      0.00      0.04         0.00
# inXile Entertainment              0.02      0.06      0.00         0.01
# mixi, Inc                         0.00      0.00      0.86         0.00
# responDESIGN                      0.09      0.04      0.00         0.01
#
#                               Global_Sales
# Publisher
# ...

# %%
#Q5
na.tail(5)[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
# Out:
# NA_Sales        0.03
# EU_Sales        0.01
# JP_Sales        0.00
# Other_Sales     0.00
# Global_Sales    0.05
# dtype: float64

# %%
#Q5
na.sort_values("Publisher",ascending=False)
# Out:
#         Rank                                    Name Platform    Year  \
# 10945  10947                        Yourself Fitness       XB  2004.0
# 13684  13686                        Yourself Fitness      PS2  2005.0
# 2409    2411                      Monster Strike 3DS      3DS  2015.0
# 10756  10758                             Wasteland 2       PC  2015.0
# 16423  16426                                 SoniPro      3DS  2014.0
# ...      ...                                     ...      ...     ...
# 13057  13059               Men of War: Assault Squad       PC  2011.0
# 13724  13726                          Off-Road Drive       PC  2011.0
# 15706  15709  Pirates: Legend of the Black Buccaneer      PS2  2006.0
# 14130  14132                    Boulder Dash: Rocks!       DS  2007.0
# 12349  12351                          Panzer Tactics       DS  2007.0
#
#               Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Q6
na.groupby(['Platform'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600         80.78      4.86      0.00         0.84         86.57
# 3DO           0.00      0.00      0.10         0.00          0.10
# 3DS          78.03     58.29     97.30        12.55        246.27
# DC            5.43      1.69      8.56         0.27         15.97
# DS          388.53    194.05    175.02        60.29        818.91
# GB          113.64     47.51     85.12         8.16        254.42
# GBA         178.43     72.49     46.56         7.51        305.62
# GC          131.94     38.32     21.34         5.13        197.14
# GEN          19.27      5.52      2.67         0.89         28.36
# GG            0.00      0.00      0.04         0.00          0.04
# N64         138.91     41.03     33.76         4.31        218.21
# NES         125.94     21.15     98.65         5.31        251.07
# NG            0.00      0.00      1.44         0.00          1.44
# ...

# %%
#Q6
na.sort_values("Platform",ascending=False)
# Out:
#         Rank                      Name Platform    Year         Genre  \
# 15052  15055     NASCAR Heat Evolution     XOne  2016.0        Racing
# 12579  12581          TrackMania Turbo     XOne  2016.0        Action
# 11305  11307           Dead or Alive 5     XOne  2015.0      Fighting
# 1605    1607  The Witcher 3: Wild Hunt     XOne  2015.0  Role-Playing
# 13174  13176                    MXGP 2     XOne  2016.0        Racing
# ...      ...                       ...      ...     ...           ...
# 1163    1165               Mario Bros.     2600  1982.0      Platform
# 1153    1155                River Raid     2600  1981.0       Shooter
# 5366    5368                   Freeway     2600  1980.0        Action
# 5381    5383            Alien's Return     2600  1982.0        Action
# 7904    7906      International Soccer     2600  1981.0        Sports
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...
